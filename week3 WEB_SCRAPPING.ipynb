# %% [markdown]
# IMPORTING ALL THE LIBRARIES NECESSARY:

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import geocoder

# %%
#!conda install -c conda-forge geocoder --yes

# %% [markdown]
# Getting all content from the wikipidea page using requests package:

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

response=requests.get(url)

# %% [markdown]
# Using BeautifulSoup library to read the html content from the wikipedia page:

# %%
soup=BeautifulSoup(response.content,'lxml')

# %% [markdown]
# Extracting and Exploring the table content from webpage:

# %%
table=soup.find_all('table',class_='wikitable sortable')
table=table[0]
type(table)
# Out:
# bs4.element.Tag

# %% [markdown]
# Writing all content of the table in a file named stats.txt in a csv format:

# %%
with open ('stats.txt', 'w') as r:
    r.write('0,Postcode,Borough,Neighbourhood')
    r.write('\n')
    for row in table.find_all('tr'):
        for cell in row.find_all('td'):
            r.write(',')
            r.write(cell.text)

# %% [markdown]
# Reading the stats.txt file as a csv file import it as a dataframe using Pandas library:

# %%
df=pd.read_csv('stats.txt')

# %% [markdown]
# PRE-PROCESSING THE DATAFRAME:

# %%
df.drop('0',axis=1,inplace=True)
df=df[df['Borough']!='Not assigned']
df.reset_index(drop=True,inplace=True)

# %%
df.head(5)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights

# %% [markdown]
# If more than one neighborhood existed in one postal code area, then merging the two rows:

# %%
for i in range(0,400):
    if i<(df.shape[0]-1):
        if df.loc[i,'Postcode']==df.loc[i+1,'Postcode']:
            df.loc[i,'Neighbourhood']=df.loc[i,'Neighbourhood']+', '+df.loc[i+1,'Neighbourhood']
            df.drop(i+1,axis=0,inplace=True)
            df.reset_index(drop=True,inplace=True)

# %% [markdown]
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough:

# %%
for i in range(0,df.shape[0]):
    if df.loc[i,'Neighbourhood']=='Not assigned':
        df.loc[i,'Neighbourhood']=df.loc[i,'Borough']

# %%
df
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood  latitude  longitude
# 0                                            Parkwoods         0          0
# 1                                     Victoria Village         1          1
# 2                            Harbourfront, Regent Park         2          2
# 3                     Lawrence Heights, Lawrence Manor         3          3
# 4                                         Queen's Park         4          4
# 5                                     Islington Avenue         5          5
# 6                                       Rouge, Malvern         6          6
# 7                                      Don Mills North         7          7
# 8                      Woodbine Gardens, Parkview Hill         8          8
# 9                             Ryerson, Garden District         9          9
# 10                                           Glencairn        10         10
# 11   Cloverdale, Islington, Martin Grove, Princess ...        11         11
# 12              Highland Creek, Rouge Hill, Port Union        14         14
# 13                    Flemingdon Park, Don Mills South        16         16
# 14                                    Woodbine Heights        17         17
# 15                                      St. James Town        18         18
# 16                                  Humewood-Cedarvale        19         19
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...        20         20
# 18                   Guildwood, Morningside, West Hill        22         22
# 19                                         The Beaches        24         24
# 20                                         Berczy Park        25         25
# 21                                 Caledonia-Fairbanks        26         26
# 22                                              Woburn        27         27
# 23                                             Leaside        28         28
# 24                                  Central Bay Street        29         29
# 25                                            Christie        30         30
# 26                                           Cedarbrae        31         31
# 27                                   Hillcrest Village        32         32
# 28     Bathurst Manor, Downsview North, Wilson Heights        33         33
# 29                                    Thorncliffe Park        35         35
# ..                                                 ...       ...        ...
# 73                                  North Toronto West        89         89
# 74                 The Annex, North Midtown, Yorkville        90         90
# 75                              Parkdale, Roncesvalles        92         92
# 76               Canada Post Gateway Processing Centre        93         93
# 77   Kingsview Village, Martin Grove Gardens, Richv...        94         94
# 78                                           Agincourt        96         96
# 79                                          Davisville        97         97
# 80                      Harbord, University of Toronto        98         98
# 81                                  Runnymede, Swansea        99         99
# 82             Clarks Corners, Sullivan, Tam O'Shanter       100        100
# 83                         Moore Park, Summerhill East       102        102
# 84           Chinatown, Grange Park, Kensington Market       103        103
# 85   Agincourt North, L'Amoreaux East, Milliken, St...       105        105
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...       107        107
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...       110        110
# 88        Humber Bay Shores, Mimico South, New Toronto       114        114
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...       116        116
# 90                                     L'Amoreaux West       120        120
# 91                                            Rosedale       121        121
# 92                     Stn A PO Boxes 25 The Esplanade       122        122
# 93                              Alderwood, Long Branch       123        123
# 94                                           Northwest       124        124
# 95                                         Upper Rouge       125        125
# 96                         Cabbagetown, St. James Town       126        126
# 97              First Canadian Place, Underground city       127        127
# 98       The Kingsway, Montgomery Road, Old Mill North       128        128
# 99                                Church and Wellesley       130        130
# 100  Business Reply Mail Processing Centre 969 Eastern       131        131
# 101  Humber Bay, King's Mill Park, Kingsway Park So...       132        132
# 102  Kingsway Park South West, Mimico NW, The Queen...       136        136
#
# [103 rows x 5 columns]

# %%
df.shape
# Out:
# (103, 5)

# %% [markdown]
# Creating two more columns for Latitude and Longitude:

# %%
df['latitude']=df.index
df['longitude']=df.index
df.head()
# Out:
#   Postcode           Borough                     Neighbourhood  latitude  \
# 0      M3A        North York                         Parkwoods         0
# 1      M4A        North York                  Victoria Village         1
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park         2
# 3      M6A        North York  Lawrence Heights, Lawrence Manor         3
# 4      M7A      Queen's Park                      Queen's Park         4
#
#    longitude
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4

# %% [markdown]
# As the Geocoder package is not working, I used the csv file provided in the assignment:

# %%
coord=pd.read_csv('Geospatial_Coordinates.csv')

# %%
coord.columns=['Postcode', 'Latitude', 'Longitude']
coord.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %% [markdown]
# Filling the correct values of latitude and longitude in main dataframe i.e. df:

# %%
for i in range(0,df.shape[0]):
    for j in range(0,coord.shape[0]):
        if df.loc[i,'Postcode']==coord.loc[j,'Postcode']:
            df.loc[i,'latitude']=coord.loc[j,'Latitude']
            df.loc[i,'longitude']=coord.loc[j,'Longitude']

# %%
df
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood   latitude  longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                         Queen's Park  43.662301 -79.389494
# 5                                     Islington Avenue  43.667856 -79.532242
# 6                                       Rouge, Malvern  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                      Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 12              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      Harbord, University of Toronto  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 85   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 90                                     L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 101  Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 102  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
import folium

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df['Borough'].unique()),
        df.shape[0]
    )
)
# Out:
# The dataframe has 11 boroughs and 103 neighborhoods.

# %% [markdown]
# Creating a map of Toronto:

# %%
latitude=43.741667
longitude=-79.373333
map = folium.Map(location=[latitude, longitude], zoom_start=10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Adding markers of Neighbourhoods in the map of Toronto:

# %%
# add markers to map
for lat, lng, borough, neighborhood in zip(df['latitude'], df['longitude'], df['Borough'], df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map)  
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Selecting a Borough=York in Toronto and exploring its neighbourhood:

# %%
york = df[df['Borough'] == 'York'].reset_index(drop=True)
york
# Out:
#   Postcode Borough                                   Neighbourhood   latitude  \
# 0      M6C    York                              Humewood-Cedarvale  43.693781
# 1      M6E    York                             Caledonia-Fairbanks  43.689026
# 2      M6M    York  Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.691116
# 3      M6N    York                   The Junction North, Runnymede  43.673185
# 4      M9N    York                                          Weston  43.706876
#
#    longitude
# 0 -79.428191
# 1 -79.453512
# 2 -79.476013
# 3 -79.487262
# 4 -79.518188

# %% [markdown]
# Creating map of York along with markers marking the Neighbourhood of York in Toronto:

# %%
map_york = folium.Map(location=[43.6957,-79.4504], zoom_start=11)

# add markers to map
for lat, lng, label in zip(york['latitude'], york['longitude'], york['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_york)  
    
map_york
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
